# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanGarcia88/Definitivo/blob/main/Taller2_Calculos_variando_la_carga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import cmath

# %%
## MEZCLADORA
TmN = 477.54526534306535
Vel = 880

# %%
Speed = np.linspace(0, 901, 3000000)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.5907
Xs = (2*np.pi*f)*(0.0009007)
Xm1 = (2*np.pi*f)*(0.03498)
R1 = 0.3492
X1 = (2*np.pi*f)*(0.004182)
R2 = 0.3503
X2 = (2*np.pi*f)*((0.0009007))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 370.10827042487097
Rth0 = 0.5603473952635081
Xth0 = 0.35550205971601345
Te_PLOT = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))

k = TmN/Vel
y_plot=k*(Speed)

punto_de_cruce = None
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce = Speed[punto_de_cruce]
    torque_cruce = Te_PLOT[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")
plt.figure(figsize=(10, 8))
plt.xlim(0, 1000)
plt.plot(Speed, Te_PLOT)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor')
plt.plot(Speed, y_plot)
plt.scatter(velocidad_cruce, torque_cruce, marker= 'x', color='red', label = 'Punto de cruce')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# El punto de cruce ocurre en Speed = 880.0000856666952 y Te_PLOT = 477.5435336609683

# %%
TmN_min = TmN * (10/100)
TmN_Max = TmN * (150/100)

# %%
Speed = np.linspace(0, 901, 3000000)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.1729
Xs = (2*np.pi*f)*(1.3856*(10**-3))
Xm1 = (2*np.pi*f)*(38.4525*(10**-3))
R1 = 0.3928
X1 = (2*np.pi*f)*(6.5173*(10**-3))
R2 = 0.3928
X2 = (2*np.pi*f)*((1.3856*10**-3))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 366.75900203560786
Rth0 = 0.16106061930589613
Xth0 = 0.5060450381022743
Te_PLOT = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))
y_plot=k*(Speed)
y_plot_min=(k*(Speed))*(10/100)
y_plot_max=(k*(Speed))*(150/100)
punto_de_cruce = None
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce = Speed[punto_de_cruce]
    torque_cruce = Te_PLOT[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")

punto_de_cruce2 = None
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot_min[i]:
        punto_de_cruce2 = i
        break
if punto_de_cruce2 is not None:
    velocidad_cruce_min = Speed[punto_de_cruce2]
    torque_cruce_min = Te_PLOT[punto_de_cruce2]
    print(f"El punto de cruce_min ocurre en Speed = {velocidad_cruce_min} y Te_PLOT_min = {torque_cruce_min}")

punto_de_cruce3 = None
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot_max[i]:
        punto_de_cruce3 = i
        break
if punto_de_cruce3 is not None:
    velocidad_cruce_max = Speed[punto_de_cruce3]
    torque_cruce_max = Te_PLOT[punto_de_cruce3]
    print(f"El punto de cruce_min ocurre en Speed = {velocidad_cruce_max} y Te_PLOT_min = {torque_cruce_max}")


plt.figure(figsize=(11, 8))
plt.plot(Speed, Te_PLOT)
plt.xlabel('Velocidad del Motor (Speed) RPM')
plt.ylabel('Torque electrico (Te) NM')
plt.title('Torque vs. Velocidad del Motor')
plt.plot(Speed, y_plot, linestyle = '--', label= 'carga al 100%')
plt.plot(Speed, y_plot_min, label= 'carga al 10%')
plt.plot(Speed, y_plot_max, label= 'carga al 150%')
plt.scatter(velocidad_cruce, torque_cruce, marker= 'x', color='orange', label = 'Punto de cruce torque nominal')
plt.annotate('Carga 100% ({}, {})'.format(round(velocidad_cruce, 2), round(torque_cruce, 2)),
             xy=(velocidad_cruce, torque_cruce),
             xytext=(velocidad_cruce + 1, torque_cruce - 60),  # Ajusté los valores aquí
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(velocidad_cruce_min, torque_cruce_min, marker= 'x', color='green', label = 'Punto de cruce torque minimo')
plt.annotate('Carga 10% ({}, {})'.format(round(velocidad_cruce_min, 2), round(torque_cruce_min, 2)),
             xy=(velocidad_cruce_min, torque_cruce_min),
             xytext=(velocidad_cruce_min + 1, torque_cruce_min - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(velocidad_cruce_max, torque_cruce_max, marker= 'x', color='red', label = 'Punto de cruce torque maximo')
plt.annotate('Carga 150% ({}, {})'.format(round(velocidad_cruce_max, 2), round(torque_cruce_max, 2)),
             xy=(velocidad_cruce_max, torque_cruce_max),
             xytext=(velocidad_cruce_max + 1, torque_cruce_max - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.xticks(np.arange(0, 901, 100), labels=np.arange(0, 901, 100))
plt.grid(True)
plt.show()
# Out:
# El punto de cruce ocurre en Speed = 879.0540353513451 y Te_PLOT = 477.0304677479826
# El punto de cruce_min ocurre en Speed = 897.9804476601491 y Te_PLOT_min = 48.7286461626821
# El punto de cruce_min ocurre en Speed = 867.3338234446078 y Te_PLOT_min = 706.0025218414127

# %%
## a minima carga
Sn0 = (900 - velocidad_cruce_min) / 900
print(Sn0)
# Out:
# 0.002243947044278735

# %%
Rr_min = (R1*R2*(R1+R2)+Sn0**2*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+Sn0**2*(X1+X2)**2)
Xr_min = (R1**2 * X2 + R2**2 * X1 + Sn0**2 * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + Sn0**2 * (X1 + X2)**2)

# %%
pp1=(1j*Xm1*((Rr_min/Sn0)+1j*Xr_min))/(1j*Xm1+((Rr_min/Sn0)+1j*Xr_min))
Zeq_min=Rs+1j*Xs+(pp1)
r0, theta0 = abs(Zeq_min), cmath.phase(Zeq_min)
print(Zeq_min)
print(f"Forma polar: {r0}∠{theta0} ")
# Out:
# (2.5031184367313797+14.61284949502127j)
# Forma polar: 14.825686232766696∠1.4011471235905564

# %%
Ie_min = 380/r0
print(Ie_min)
# Out:
# 25.63119130095648

# %%
Pin_N_min = (3 * 380 * Ie_min) * (np.cos(theta0))
print(Pin_N_min)
# Out:
# 4933.330801867235

# %%
Pcu_E_min = (3 * (Ie_min**2) * Rs )
print(Pcu_E_min)
# Out:
# 340.76409774548

# %%
Vth = 380*(((Xm1)/((Rs**2)+((Xs+Xm1)**2))**0.5))
print(Vth)
# Out:
# 366.75900203560786

# %%
Zth = (((complex(0, Xm1))*(Rs + complex(0, Xs))/(Rs + (complex(0, Xs)+ complex(0, Xm1)))))
Rth = Zth.real
Xth = Zth.imag

# %%
Ws = ((2*np.pi)/60)*900
print(Ws)
# Out:
# 94.24777960769379

# %%
Te_N = (((3*(Vth**2))*(Rr_min/Sn0))/((Ws*((Rth + (Rr_min/Sn0))**2+((Xth + Xr_min)**2)))))
print(Te_N)
# Out:
# 48.7286461626821

# %%
Is_N = 380/Zeq_min
y, z = abs(Is_N), cmath.phase(Is_N)
print(f"Forma polar: {y}∠{z} ")
# Out:
# Forma polar: 25.63119130095648∠-1.4011471235905564

# %%
Pin_N = 380*y*np.cos(z)
print(f"Potencia de entrada: {Pin_N} ")
print(f"Factor de potencia a carga minima: {np.cos(z)}")
# Out:
# Potencia de entrada: 1644.4436006224116
# Factor de potencia a carga minima: 0.16883659868635031

# %%
## a maxima carga
Sn01 = (900 - velocidad_cruce_max ) / 900
print(Sn01)
# Out:
# 0.03629575172821357

# %%
Rr_max = (R1*R2*(R1+R2)+Sn01**2*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+Sn01**2*(X1+X2)**2)
Xr_max = (R1**2 * X2 + R2**2 * X1 + Sn01**2 * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + Sn01**2 * (X1 + X2)**2)

# %%
pp01=(1j*Xm1*((Rr_min/Sn01)+1j*Xr_min))/(1j*Xm1+((Rr_min/Sn01)+1j*Xr_min))
Zeq_max=Rs+1j*Xs+(pp01)
r01, theta01 = abs(Zeq_max), cmath.phase(Zeq_max)
print(Zeq_max)
print(f"Forma polar: {r01}∠{theta01} ")
# Out:
# (4.520200003376143+2.774257820585826j)
# Forma polar: 5.303651056169071∠0.5504660956482751

# %%
Ie_max = 380/r01
print(Ie_max)
# Out:
# 71.64875591843354

# %%
Te_N_max = (((3*(Vth**2))*(Rr_max/Sn01))/((Ws*((Rth + (Rr_max/Sn01))**2+((Xth + Xr_min)**2)))))
print(Te_N_max)
# Out:
# 705.6927351405733

# %%
Is_N_max = 380/Zeq_max
y1, z1 = abs(Is_N_max), cmath.phase(Is_N_max)
print(f"Forma polar: {y1}∠{z1} ")
Is_N_max
# Out:
# Forma polar: 71.64875591843355∠-0.5504660956482751
# (61.06485953062209-37.47835582258991j)

# %%
Pin_N1 = 380*y1*np.cos(z1)
print(f"Potencia de entrada: {Pin_N1} ")
print(f"Factor de potencia a carga minima: {np.cos(z1)}")
# Out:
# Potencia de entrada: 23204.646621636395
# Factor de potencia a carga minima: 0.8522808072221045

# %%
## nominal
Nomi = 43.793967588697846-27.637277705734455j
y2, z2 = abs(Nomi), cmath.phase(Nomi)

Pin_N2 = 380*y2*np.cos(z2)
print(f"Potencia de entrada: {Pin_N2} ")
print(f"Factor de potencia a carga nominal: {np.cos(z2)}")
# Out:
# Potencia de entrada: 16641.707683705183
# Factor de potencia a carga nominal: 0.8456812649643082

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)

pp0=(1j*Xm1*((Rr_plot/Sn_plot)+1j*Xr_plot))/(1j*Xm1+((Rr_plot/Sn_plot)+1j*Xr_plot))

Zeq_plot=Rs+1j*Xs+(pp0)
r_plot = abs(Zeq_plot)
Ie = 380/r_plot


plt.figure(figsize=(10, 8))
plt.plot(Speed, Ie)
plt.xlabel('Velocidad del Motor (Speed) RPM')
plt.ylabel('Corriente del Motor (Ie) A')
plt.title('Corriente vs. Velocidad del Motor')
plt.scatter(velocidad_cruce_min, Ie_min, marker= 'o', color='green', label='Ie_min')
plt.annotate('Carga 10%  ({}, {}, {})'.format(round(velocidad_cruce_min,2), round(Ie_min,2), round(np.cos(z), 4)),
             xy=(velocidad_cruce_min, Ie_min),
             xytext=(velocidad_cruce_min+1, Ie_min+50),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(velocidad_cruce_max, Ie_max, marker= 'o', color='red', label='Ie_max')
plt.annotate('Carga 150%  ({}, {}, {})'.format(round(velocidad_cruce_max,2), round(Ie_max,2), round(np.cos(z1), 4)),
             xy=(velocidad_cruce_max, Ie_max),
             xytext=(velocidad_cruce_max+1, Ie_max+150),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.scatter(velocidad_cruce, 51.78542957380776, marker= 'o', color='orange', label='Ie_nominal')
plt.annotate('Carga 100%  ({}, {}, {})'.format(round(velocidad_cruce ,2), round(51.78542957380776,2), round(np.cos(z2), 4)),
             xy=(velocidad_cruce, 51.78542957380776),
             xytext=(velocidad_cruce+1, 51.78542957380776+100),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.xticks(np.arange(0, 901, 100), labels=np.arange(0, 901, 100))
plt.grid(True)
plt.show()
