# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanGarcia88/Definitivo/blob/main/Taller2_Variando_la_tension_del_estator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **<font color="black"><center>Con Ve al 100%**

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import cmath
import math


## MEZCLADORA
TmN = 477.54526534306535
Vel = 880
k = TmN/Vel
## Con Ve al 100 %
Speed = np.linspace(0, 901, 3000000)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.5907
Xs = (2*np.pi*f)*(0.0009007)
Xm1 = (2*np.pi*f)*(0.03498)
R1 = 0.3492
X1 = (2*np.pi*f)*(0.004182)
R2 = 0.3503
X2 = (2*np.pi*f)*((0.0009007))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 370.10827042487097
Rth0 = 0.5603473952635081
Xth0 = 0.35550205971601345
Te_PLOT2 = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))

y_plot=k*(Speed)
Te_PLOT = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))
punto_de_cruce = None
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce= Speed[punto_de_cruce]
    torque_cruce= Te_PLOT[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")
plt.figure(figsize=(10, 8))
plt.xlim(0, 1000)
plt.plot(Speed, Te_PLOT)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor')
plt.plot(Speed, y_plot)
plt.scatter(velocidad_cruce, torque_cruce, marker= 'x', color='red', label = 'Punto de cruce')
plt.annotate('Tension 100% ({}, {})'.format(round(velocidad_cruce, 2), round(torque_cruce, 2)),
             xy=(velocidad_cruce, torque_cruce),
             xytext=(velocidad_cruce + 1, torque_cruce - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# El punto de cruce ocurre en Speed = 880.0000856666952 y Te_PLOT = 477.5435336609683

# %%
Nomi = 43.793967588697846-27.637277705734455j
y2, z2 = abs(Nomi), cmath.phase(Nomi)

Pin_N2 = 380*y2*np.cos(z2)
print(f"Potencia de entrada: {Pin_N2} ")
print(f"Factor de potencia a carga nominal: {np.cos(z2)}")
# Out:
# Potencia de entrada: 16641.707683705183
# Factor de potencia a carga nominal: 0.8456812649643082

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)

pp0=(1j*Xm1*((Rr_plot/Sn_plot)+1j*Xr_plot))/(1j*Xm1+((Rr_plot/Sn_plot)+1j*Xr_plot))

Zeq_plot=Rs+1j*Xs+(pp0)
r_plot = abs(Zeq_plot)
Ie = 380/r_plot


plt.figure(figsize=(10, 8))
plt.plot(Speed, Ie)
plt.xlabel('Velocidad del Motor (Speed) RPM')
plt.ylabel('Corriente del Motor (Ie) A')
plt.scatter(velocidad_cruce, 51.78542957380776, marker= 'o', color='orange', label='Ie_nominal')
plt.annotate('tension 100%  ({}, {}, {})'.format(round(velocidad_cruce ,2), round(51.78542957380776,2), round(np.cos(z2), 4)),
             xy=(velocidad_cruce, 51.78542957380776),
             xytext=(velocidad_cruce+1, 51.78542957380776+100),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.title('Corriente vs. Velocidad del Motor')
plt.legend(loc='upper right')
plt.xticks(np.arange(0, 901, 100), labels=np.arange(0, 901, 100))
plt.grid(True)
plt.show()

# %% [markdown]
# # **<font color="black"><center>Con Ve al 35%**

# %%
Ve2 = (35 * 380) / 100

# %%
Vth2 = Ve2*(((Xm1)/((Rs**2)+((Xs+Xm1)**2))**0.5))

# %%
Speed = np.linspace(0, 901, 3000000)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.5907
Xs = (2*np.pi*f)*(0.0009007)
Xm1 = (2*np.pi*f)*(0.03498)
R1 = 0.3492
X1 = (2*np.pi*f)*(0.004182)
R2 = 0.3503
X2 = (2*np.pi*f)*((0.0009007))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 370.10827042487097
Rth0 = 0.5603473952635081
Xth0 = 0.35550205971601345
Te_PLOT2 = (((3*(Vth2**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))
y_plot=k*(Speed)
punto_de_cruce = None
for i in range(len(Speed)):
    if Te_PLOT2[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce_35 = Speed[punto_de_cruce]
    torque_cruce_35 = Te_PLOT2[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")


plt.figure(figsize=(11, 8))
plt.xlim(0, 1000)
plt.plot(Speed, Te_PLOT2)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor')
plt.plot(Speed, y_plot)
plt.ylim(0, 200)
plt.scatter(velocidad_cruce_35, torque_cruce_35, marker= 'x', color='red', label = 'Punto de cruce')
plt.annotate('Tension 35% ({}, {})'.format(round(velocidad_cruce_35, 2), round(torque_cruce_35, 2)),
             xy=(velocidad_cruce_35, torque_cruce_35),
             xytext=(velocidad_cruce_35 + 1, torque_cruce_35 - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# El punto de cruce ocurre en Speed = 880.0000856666952 y Te_PLOT = 477.5435336609683

# %%
## con Ve al 35%
Sn0 = (900 - velocidad_cruce_35) / 900
print(Sn0)
# Out:
# 0.7129372998679888

# %%
Rr_min = (R1*R2*(R1+R2)+Sn0**2*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+Sn0**2*(X1+X2)**2)
Xr_min = (R1**2 * X2 + R2**2 * X1 + Sn0**2 * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + Sn0**2 * (X1 + X2)**2)

pp1=(1j*Xm1*((Rr_min/Sn0)+1j*Xr_min))/(1j*Xm1+((Rr_min/Sn0)+1j*Xr_min))
Zeq_min=Rs+1j*Xs+(pp1)
r0, theta0 = abs(Zeq_min), cmath.phase(Zeq_min)


Ie_min = 380/Zeq_min
y, z = abs(Ie_min), cmath.phase(Ie_min)
Pin_N = 380*y*np.cos(z)
print(f"Potencia de entrada: {Pin_N} ")
print(f"Factor de potencia a carga minima: {np.cos(z)}")
# Out:
# Potencia de entrada: 104214.63109748576
# Factor de potencia a carga minima: 0.8067668132810089

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)

pp0=(1j*Xm1*((Rr_plot/Sn_plot)+1j*Xr_plot))/(1j*Xm1+((Rr_plot/Sn_plot)+1j*Xr_plot))

Zeq_plot=Rs+1j*Xs+(pp0)
r_plot = abs(Zeq_plot)
Ie = 380/r_plot


plt.figure(figsize=(10, 8))
plt.plot(Speed, Ie)
plt.xlabel('Velocidad del Motor (Speed) RPM')
plt.ylabel('Corriente del Motor (Ie) A')
plt.scatter(velocidad_cruce_35,y, marker= 'o', color='orange', label='Ie_con_Ve_35')
plt.annotate('tension 35%  ({}, {}, {})'.format(round(velocidad_cruce_35 ,2), round(y), round(np.cos(z), 4)),
             xy=(velocidad_cruce_35, y),
             xytext=(velocidad_cruce_35+1, y-100),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.title('Corriente vs. Velocidad del Motor')
plt.legend(loc='upper right')
plt.xticks(np.arange(0, 901, 100), labels=np.arange(0, 901, 100))
plt.grid(True)
plt.show()

# %% [markdown]
# # **<font color="black"><center>Comparando las dos**

# %%
Speed = np.linspace(0, 901, 3000000)
Sn_plot=(900-Speed)/900

f=60
Rs = 0.5907
Xs = (2*np.pi*f)*(0.0009007)
Xm1 = (2*np.pi*f)*(0.03498)
R1 = 0.3492
X1 = (2*np.pi*f)*(0.004182)
R2 = 0.3503
X2 = (2*np.pi*f)*((0.0009007))
Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)
Ws = 94.24777960769379
Vth0 = 366.75900203560786
Rth0 = 0.16106061930589613
Xth0 = 0.5060450381022743
T2 = (((3*(Vth2**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))
Te_PLOT0 = (((3*(Vth0**2))*(Rr_plot/Sn_plot))/((Ws*((Rth0 + (Rr_plot/Sn_plot))**2+((Xth0 + Xr_plot)**2)))))
for i in range(len(Speed)):
    if Te_PLOT[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce = Speed[punto_de_cruce]
    torque_cruce = Te_PLOT[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")

for i in range(len(Speed)):
    if T2[i] <= y_plot[i]:
        punto_de_cruce = i
        break
if punto_de_cruce is not None:
    velocidad_cruce2 = Speed[punto_de_cruce]
    torque_cruce2 = T2[punto_de_cruce]
    print(f"El punto de cruce ocurre en Speed = {velocidad_cruce} y Te_PLOT = {torque_cruce}")


plt.figure(figsize=(11, 8))
plt.plot(Speed, T2, label = 'Al 35%', linewidth=1)
plt.plot(Speed, Te_PLOT0, linestyle = '--', label = 'Al 100 %',linewidth=1)
plt.xlabel('Velocidad del Motor (Speed)')
plt.ylabel('Torque electrico (Te)')
plt.title('Torque vs. Velocidad del Motor al 35%')
plt.plot(Speed, y_plot)
plt.scatter(velocidad_cruce, torque_cruce, marker= 'x', color='red', label = 'Punto de cruce')
plt.scatter(velocidad_cruce2, torque_cruce2, marker= 'x', color='red', label = 'Punto de cruce')
plt.annotate('Tension 35% ({}, {})'.format(round(velocidad_cruce2, 2), round(torque_cruce2, 2)),
             xy=(velocidad_cruce2, torque_cruce2),
             xytext=(velocidad_cruce2 + 1, torque_cruce2 - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate('Tension 100% ({}, {})'.format(round(velocidad_cruce, 2), round(torque_cruce, 2)),
             xy=(velocidad_cruce, torque_cruce),
             xytext=(velocidad_cruce + 1, torque_cruce - 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.grid(True)
plt.show()
# Out:
# El punto de cruce ocurre en Speed = 880.0000856666952 y Te_PLOT = 477.5435336609683
# El punto de cruce ocurre en Speed = 880.0000856666952 y Te_PLOT = 477.5435336609683

# %%
Speed = np.linspace(0, 901, 100)
Sn_plot=(900-Speed)/900

Rr_plot= (R1*R2*(R1+R2)+(Sn_plot**2)*(R1*X2**2+R2*X1**2)) / ((R1+R2)**2+(Sn_plot)**2*(X1+X2)**2)
Xr_plot = (R1**2 * X2 + R2**2 * X1 + (Sn_plot**2) * X1 * X2 * (X1 + X2)) / ((R1 + R2)**2 + (Sn_plot**2) * (X1 + X2)**2)

pp0=(1j*Xm1*((Rr_plot/Sn_plot)+1j*Xr_plot))/(1j*Xm1+((Rr_plot/Sn_plot)+1j*Xr_plot))

Zeq_plot=Rs+1j*Xs+(pp0)
r_plot = abs(Zeq_plot)
Ie = 380/r_plot


plt.figure(figsize=(10, 8))
plt.plot(Speed, Ie)
plt.xlabel('Velocidad del Motor (Speed) RPM')
plt.ylabel('Corriente del Motor (Ie) A')
plt.scatter(velocidad_cruce, 51.78542957380776, marker= 'o', color='purple', label='Ie_nominal')
plt.annotate('tension 100%  ({}, {}, {})'.format(round(velocidad_cruce ,2), round(51.78542957380776,2), round(np.cos(z2), 4)),
             xy=(velocidad_cruce, 51.78542957380776),
             xytext=(velocidad_cruce+1, 51.78542957380776+100),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.title('Corriente vs. Velocidad del Motor')
plt.scatter(velocidad_cruce_35,y, marker= 'o', color='red', label='Ie_con_Ve_35')
plt.annotate('tension 35%  ({}, {}, {})'.format(round(velocidad_cruce_35 ,2), round(y), round(np.cos(z), 4)),
             xy=(velocidad_cruce_35, y),
             xytext=(velocidad_cruce_35+1, y-100),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.legend(loc='upper right')
plt.xticks(np.arange(0, 901, 100), labels=np.arange(0, 901, 100))
plt.grid(True)
plt.show()

# %%
Ie_mayor_St = 2.87 * 48.4436616673225

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Ve_new = 1.0396621246652835 * Ie_mayor_St
print(Ve_new)
# Out:
# 144.5476654188141

# %%
f = (Ve_new/380)*100
print(f)
# Out:
# 38.03885932074055

# %% [markdown]
# # **<font color="black">Se debe aplicar una tension 38.03% mayor a la nominal**

# %%
Te_new_St = 477.545265343065357 * 0.37

# %%
Vth_new =  math.sqrt(Te_new_St / (3 * 0.2395011828970842 * Ws * (Rth0**2 + 2 * Rth0 * (0.2395011828970842) + (0.2395011828970842)**2 + (Xth0 + 0.302976027832952)**2)))

# %%
Ve_new2 =  Vth_new / (Xm1 / (((Rs**2) + ((Xs + Xm1)**2))**0.5))

print(Ve_new2)
# Out:
# 1.600818177679486

# %%
f1 = (Ve_new2/380)*100
print(f1)
# Out:
# 0.4212679414946016

# %% [markdown]
# # **<font color="black">Se debe aplicar una tension 0.49% mayor a la nominal**
